# %% [markdown]
# ## Procesamiento de Imágenes - UNS - Doctorado
#
# Trabajo Práctico 0

# %%
# load and display an image with Matplotlib
import os
import numpy as np

from matplotlib import image
from matplotlib import pyplot
from matplotlib.widgets import Slider

# %%
# load image as pixel array
image = image.imread(os.path.join(os.getcwd(), "shely720x521.jpg"))

# %%
# Función para actualizar la imagen modificada        
img_copy = image.copy()

# Crear una figura y un eje
fig, ax = pyplot.subplots()

# Mostrar la imagen original
ax.imshow(img_copy)

# %%
axcolor = "lightgoldenrodyellow"
ax_rojo = pyplot.axes([0.2, 0.02, 0.65, 0.03], facecolor=axcolor)
ax_verde = pyplot.axes([0.2, 0.06, 0.65, 0.03], facecolor=axcolor)
ax_azul = pyplot.axes([0.2, 0.1, 0.65, 0.03], facecolor=axcolor)

s_rojo = Slider(ax_rojo, "Rojo", 0, 1, valinit=1)
s_verde = Slider(ax_verde, "Verde", 0, 1, valinit=1)
s_azul = Slider(ax_azul, "Azul", 0, 1, valinit=1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 6
#       3 ax_verde = pyplot.axes([0.2, 0.06, 0.65, 0.03], facecolor=axcolor)
#       4 ax_azul = pyplot.axes([0.2, 0.1, 0.65, 0.03], facecolor=axcolor)
# ----> 6 s_rojo = Slider(ax_rojo, "Rojo", 0, 1, valinit=1)
#       7 s_verde = Slider(ax_verde, "Verde", 0, 1, valinit=1)
#       8 s_azul = Slider(ax_azul, "Azul", 0, 1, valinit=1)
#
# NameError: name 'Slider' is not defined

# %%
axcolor = "lightgoldenrodyellow"
rojo_slider = pyplot.axes([0.25, 0.1, 0.65, 0.03], facecolor=axcolor)
verde_slider = pyplot.axes([0.25, 0.05, 0.65, 0.03], facecolor=axcolor)
azul_slider = pyplot.axes([0.25, 0.0, 0.65, 0.03], facecolor=axcolor)

# %%
s_rojo = pyplot.Slider(rojo_slider, "Rojo", 0.0, 1.0, valinit=1.0)
s_verde = pyplot.Slider(verde_slider, "Verde", 0.0, 1.0, valinit=0.0)
s_azul = pyplot.Slider(azul_slider, "Azul", 0.0, 1.0, valinit=0.0)

# %%
s_rojo.on_changed(lambda val: ModifyImage(image).modify_image())
s_verde.on_changed(lambda val: ModifyImage(image).modify_image())
s_azul.on_changed(lambda val: ModifyImage(image).modify_image())
# Out:
# 0

# %%
pyplot.show()
